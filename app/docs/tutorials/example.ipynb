# %% [markdown]
# # Пример ноутбука
#
# Это демонстрация автоматической конвертации Jupyter notebooks в документацию.

# %%
import svetlanna as sp
print("Hello from SVETlANNa!")
# Out:
# Hello from SVETlANNa!

# %% [markdown]
# ## Создание параметров симуляции

# %%
params = sp.SimulationParameters(
    wavelength=[500e-9],
    size=(512, 512),
    pitch=1e-6
)
params
# Out:
# SimulationParameters(wavelength=[500nm], size=512x512, pitch=1.0um)
